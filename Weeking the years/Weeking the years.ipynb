# %%
year = 2024
minerva_week = True
#add the days to drop from the weeks counting here
to_drop = []
# ["01-1-2024"]

# %%
import datetime  
from datetime import date
import calendar
import pandas as pd

def findDay(date):
    month, day, year = (int(part) for part in date.split('-'))     
    born = datetime.date(year, month, day) 
    return born.strftime("%A")

# %%
if (year % 100 and year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    feb_last = 29
else:
    feb_last = 28

small_months = ["04", "06", "09", "11"]
big_months = ["01", "03", "05", "07", "08", "10", "12"]
months_lst = small_months + big_months + ["02"]
months_lst.sort()
months = {}
for key in months_lst:
    if key in small_months:
        months[key] = 30
    elif key in big_months:
        months[key] = 31
    else:
        months[key] = feb_last

year_days = []
for month_key in months:
    days = []
    for day_index in range(1, months[month_key] + 1):
        day_to_append = month_key + "-" + str(day_index) +  "-" + str(year)
        if day_to_append not in to_drop:
            year_days.append(day_to_append)

# %%
weeks_lst = []
for week in range(51):
    weeks_lst.append(week)
year_weeks = {week:[] for week in weeks_lst}

week_to_fill = []
week_index = 0
for day in year_days:
    if len(week_to_fill) < 7:
        week_to_fill.append(day)
    #Normal human weeks start on Monday but Minerva academic weeks start on Sunday
    if minerva_week == True:
        if findDay(day) == "Sunday":
            year_weeks[week_index] = week_to_fill
            week_index += 1
            week_to_fill = []
    elif minerva_week == False:
        if findDay(day) == "Monday":
            year_weeks[week_index] = week_to_fill
            week_index += 1
            week_to_fill = []

#for week in year_weeks:
#    print(week, len(year_weeks[week]))

# %%
spring = {}
summer = {}
fall = {}

for week_index_key in year_weeks:
    if week_index_key <= 16:
        week_key = "Week " + str(week_index_key)
        spring[week_key] = year_weeks[week_index_key]
    elif week_index_key <= 34:
        week_key = "Week " + str(week_index_key - 16)
        summer[week_key] = year_weeks[week_index_key]
    elif week_index_key <= 51:
        week_key = "Week " + str(week_index_key - 34)
        fall[week_key] = year_weeks[week_index_key]

# %%
def dict_to_csv(season_week_dict, season):
    n_weeks = len(season_week_dict)
    weeks_header = ["Week " + str(week) for week in range(0, n_weeks)]

    season_weeks = [season_week_dict[week] for week in season_week_dict]
    season_df = pd.DataFrame(list(season_weeks)).transpose()

    sample_week = spring['Week 1']
    week_days_order = [findDay(sample_week[day_index]) for day_index in range(len(sample_week))]

    season_df.index = week_days_order
    season_df.columns = weeks_header
    season_df.to_csv(path_or_buf = season + "_Sat " + str(year) + ".csv")

    # if minerva_week == True:
    #     season_df.index = ["Sun", 'Mon', 'Tue', 'Wed', "Thu", "Fri", "Sat"]
    #     season_df.columns = weeks_header
    #     season_df.to_csv(path_or_buf = season + "_Sat " + str(year) + ".csv")
    # elif minerva_week == False:
    #     season_df.index == ['Mon', 'Tue', 'Wed', "Thu", "Fri", "Sat", "Sun"]
    #     season_df.columns = weeks_header
    #     season_df.to_csv(path_or_buf = season + " " + str(year) + ".csv")

    return season_df

dict_to_csv(spring, "spring")
# Out:
#               Week 0      Week 1      Week 2      Week 3      Week 4  \
# Monday     01-1-2024   01-8-2024  01-15-2024  01-22-2024  01-29-2024
# Tuesday    01-2-2024   01-9-2024  01-16-2024  01-23-2024  01-30-2024
# Wednesday  01-3-2024  01-10-2024  01-17-2024  01-24-2024  01-31-2024
# Thursday   01-4-2024  01-11-2024  01-18-2024  01-25-2024   02-1-2024
# Friday     01-5-2024  01-12-2024  01-19-2024  01-26-2024   02-2-2024
# Saturday   01-6-2024  01-13-2024  01-20-2024  01-27-2024   02-3-2024
# Sunday     01-7-2024  01-14-2024  01-21-2024  01-28-2024   02-4-2024
#
#                Week 5      Week 6      Week 7      Week 8      Week 9  \
# Monday      02-5-2024  02-12-2024  02-19-2024  02-26-2024   03-4-2024
# Tuesday     02-6-2024  02-13-2024  02-20-2024  02-27-2024   03-5-2024
# Wednesday   02-7-2024  02-14-2024  02-21-2024  02-28-2024   03-6-2024
# Thursday    02-8-2024  02-15-2024  02-22-2024  02-29-2024   03-7-2024
# Friday      02-9-2024  02-16-2024  02-23-2024   03-1-2024   03-8-2024
# Saturday   02-10-2024  02-17-2024  02-24-2024   03-2-2024   03-9-2024
# Sunday     02-11-2024  02-18-2024  02-25-2024   03-3-2024  03-10-2024
#
#               Week 10     Week 11     Week 12    Week 13     Week 14  \
# Monday     03-11-2024  03-18-2024  03-25-2024  04-1-2024   04-8-2024
# Tuesday    03-12-2024  03-19-2024  03-26-2024  04-2-2024   04-9-2024
# Wednesday  03-13-2024  03-20-2024  03-27-2024  04-3-2024  04-10-2024
# Thursday   03-14-2024  03-21-2024  03-28-2024  04-4-2024  04-11-2024
# Friday     03-15-2024  03-22-2024  03-29-2024  04-5-2024  04-12-2024
# Saturday   03-16-2024  03-23-2024  03-30-2024  04-6-2024  04-13-2024
# Sunday     03-17-2024  03-24-2024  03-31-2024  04-7-2024  04-14-2024
#
#               Week 15     Week 16
# Monday     04-15-2024  04-22-2024
# Tuesday    04-16-2024  04-23-2024
# Wednesday  04-17-2024  04-24-2024
# Thursday   04-18-2024  04-25-2024
# Friday     04-19-2024  04-26-2024
# Saturday   04-20-2024  04-27-2024
# Sunday     04-21-2024  04-28-2024
