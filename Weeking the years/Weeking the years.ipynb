# %%
year = 2022
minerva_week = False
#add the days to drop from the weeks counting here
to_drop = []
#"08-22-2022", "08-23-2022", "08-24-2022", "08-25-2022", "08-26-2022", "08-27-2022"

# %%
import datetime  
from datetime import date
import calendar
import pandas as pd

def findDay(date):
    month, day, year = (int(part) for part in date.split('-'))     
    born = datetime.date(year, month, day) 
    return born.strftime("%A")

# %%
if (year % 100 and year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    feb_last = 29
else:
    feb_last = 28

small_months = ["04", "06", "09", "11"]
big_months = ["01", "03", "05", "07", "08", "10", "12"]
months_lst = small_months + big_months + ["02"]
months_lst.sort()
months = {}
for key in months_lst:
    if key in small_months:
        months[key] = 30
    elif key in big_months:
        months[key] = 31
    else:
        months[key] = feb_last

year_days = []
for month_key in months:
    days = []
    for day_index in range(1, months[month_key] + 1):
        day_to_append = month_key + "-" + str(day_index) +  "-" + str(year)
        if day_to_append not in to_drop:
            year_days.append(day_to_append)

# %%
weeks_lst = []
for week in range(51):
    weeks_lst.append(week)
year_weeks = {week:[] for week in weeks_lst}

week_to_fill = []
week_index = 0
for day in year_days:
    if len(week_to_fill) < 7:
        week_to_fill.append(day)
    #Normal human weeks sgtart on Monday but Minerva weeks start on Sunday
    if minerva_week == True:
        if findDay(day) == "Saturday":
            year_weeks[week_index] = week_to_fill
            week_index += 1
            week_to_fill = []
    elif minerva_week == False:
        if findDay(day) == "Sunday":
            year_weeks[week_index] = week_to_fill
            week_index += 1
            week_to_fill = []

#for week in year_weeks:
#    print(week, len(year_weeks[week]))

# %%
spring = {}
summer = {}
fall = {}

for week_index_key in year_weeks:
    if week_index_key <= 16:
        week_key = "Week " + str(week_index_key)
        spring[week_key] = year_weeks[week_index_key]
    elif week_index_key <= 34:
        week_key = "Week " + str(week_index_key - 16)
        summer[week_key] = year_weeks[week_index_key]
    elif week_index_key <= 51:
        week_key = "Week " + str(week_index_key - 34)
        fall[week_key] = year_weeks[week_index_key]

# %%
def dict_to_csv(season_week_dict, season):
    n_weeks = len(season_week_dict)
    weeks_header = ["Week " + str(week) for week in range(0, n_weeks)]

    season_weeks = [season_week_dict[week] for week in season_week_dict]
    season_df = pd.DataFrame(list(season_weeks)).transpose()
    if minerva_week == True:
        season_df.index = ["Sun", 'Mon', 'Tue', 'Wed', "Thu", "Fri", "Sat"]
        season_df.columns = weeks_header
        season_df.to_csv(path_or_buf = season + "_Sat " + str(year) + ".csv")
    elif minerva_week == False:
        season_df.index == ['Mon', 'Tue', 'Wed', "Thu", "Fri", "Sat", "Sun"]
        season_df.columns = weeks_header
        season_df.to_csv(path_or_buf = season + " " + str(year) + ".csv")

    return season_df

dict_to_csv(fall, "Fall")
# Out:
#        Week 0      Week 1      Week 2      Week 3      Week 4     Week 5  \
# 0  08-29-2022   09-5-2022  09-12-2022  09-19-2022  09-26-2022  10-3-2022
# 1  08-30-2022   09-6-2022  09-13-2022  09-20-2022  09-27-2022  10-4-2022
# 2  08-31-2022   09-7-2022  09-14-2022  09-21-2022  09-28-2022  10-5-2022
# 3   09-1-2022   09-8-2022  09-15-2022  09-22-2022  09-29-2022  10-6-2022
# 4   09-2-2022   09-9-2022  09-16-2022  09-23-2022  09-30-2022  10-7-2022
# 5   09-3-2022  09-10-2022  09-17-2022  09-24-2022   10-1-2022  10-8-2022
# 6   09-4-2022  09-11-2022  09-18-2022  09-25-2022   10-2-2022  10-9-2022
#
#        Week 6      Week 7      Week 8      Week 9     Week 10     Week 11  \
# 0  10-10-2022  10-17-2022  10-24-2022  10-31-2022   11-7-2022  11-14-2022
# 1  10-11-2022  10-18-2022  10-25-2022   11-1-2022   11-8-2022  11-15-2022
# 2  10-12-2022  10-19-2022  10-26-2022   11-2-2022   11-9-2022  11-16-2022
# 3  10-13-2022  10-20-2022  10-27-2022   11-3-2022  11-10-2022  11-17-2022
# 4  10-14-2022  10-21-2022  10-28-2022   11-4-2022  11-11-2022  11-18-2022
# 5  10-15-2022  10-22-2022  10-29-2022   11-5-2022  11-12-2022  11-19-2022
# 6  10-16-2022  10-23-2022  10-30-2022   11-6-2022  11-13-2022  11-20-2022
#
#       Week 12     Week 13     Week 14     Week 15     Week 16
# 0  11-21-2022  11-28-2022   12-5-2022  12-12-2022  12-19-2022
# 1  11-22-2022  11-29-2022   12-6-2022  12-13-2022  12-20-2022
# 2  11-23-2022  11-30-2022   12-7-2022  12-14-2022  12-21-2022
# 3  11-24-2022   12-1-2022   12-8-2022  12-15-2022  12-22-2022
# 4  11-25-2022   12-2-2022   12-9-2022  12-16-2022  12-23-2022
# 5  11-26-2022   12-3-2022  12-10-2022  12-17-2022  12-24-2022
# 6  11-27-2022   12-4-2022  12-11-2022  12-18-2022  12-25-2022
